# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import os
import json

# %%
# Replace the placeholder with your Atlas connection string
uri = "mongodb+srv://polydorouc:Leox9yW8lrfN1SKG@main.3vgxubm.mongodb.net/?retryWrites=true&w=majority"

# Set the Stable API version when creating a new client
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# listing the databases
database_names = client.list_database_names()
for db_name in database_names:
    print(db_name)
# Out:
# qa-repo
# admin
# local

# %%
db = client['qa-repo']

collections = db.list_collection_names()

# Print the list of collections
for collection_name in collections:
    print(collection_name)

collection = db['qa']
# Out:
# qa

# %%
try:
    # Example of finding a document by a specific key-value pair
    result = collection.find_one({"problem_name": "binary_search"})

    # Printing the retrieved object
    if result:
        print(f"Retrieved Object: {result}")
    else:
        print("No matching object found.")

except Exception as e:
    print(f"An error occurred: {e}")

type(result)
# Out:
# Retrieved Object: {'_id': ObjectId('65287752a8a449a24cc3f968'), 'input_arrays': [[-9997, -9991, -9981, -9978, -9975, -9968, -9967, -9963, -9961, -9959, -9954, -9948, -9946, -9920, -9918, -9917, -9907, -9895, -9890, -9883, -9879, -9874, -9865, -9857, -9854, -9853, -9845, -9841, -9837, -9834, -9810, -9808, -9807, -9804, -9801, -9793, -9786, -9783, -9782, -9777, -9760, -9755, -9744, -9742, -9741, -9731, -9730, -9720, -9706, -9699, -9682, -9679, -9667, -9664, -9657, -9645, -9642, -9640, -9638, -9632, -9625, -9618, -9617, -9610, -9599, -9598, -9592, -9587, -9581, -9572, -9571, -9568, -9566, -9561, -9550, -9549, -9544, -9538, -9533, -9530, -9529, -9528, -9520, -9512, -9498, -9495, -9489, -9462, -9451, -9446, -9442, -9436, -9422, -9421, -9416, -9411, -9407, -9398, -9396, -9390, -9388, -9386, -9377, -9374, -9372, -9364, -9362, -9356, -9347, -9330, -9329, -9328, -9325, -9324, -9322, -9320, -9318, -9305, -9288, -9278, -9276, -9252, -9250, -9244, -9242, -9241, -9239, -9237, -9235, -9232, -9227, -9212, -9204, -9203, -9190, -9164, -9149, -9142, -9133, -9114, -9092, -9089, -9073, -9072, -9065, -9062, -9058, -9055, -9052, -9047, -9039, -9036, -9030, -9027, -9019, -9014, -9013, -9011, -9009, -9008, -8988, -8984, -8980, -8977, -8976, -8972, -8971, -8970, -8962, -8958, -8956, -8952, -8943, -8932, -8928, -8924, -8917, -8916, -8911, -8900, -8896, -8892, -8875, -8874, -8865, -8864, -8853, -8850, -8841, -8832, -8823, -8817, -8801, -8799, -8786, -8768, -8766, -8754, -8752, -8750, -8744, -8741, -8735, -8732, -8723, -8702, -8698, -8695, -8694, -8692, -8689, -8685, -8670, -8664, -8662, -8659, -8650, -8641, -8624, -8609, -8606, -8605, -8600, -8599, -8598, -8596, -8594, -8588, -8581, -8580, -8574, -8570, -8554, -8551, -8549, -8538, -8535, -8534, -8526, -8524, -8513, -8511, -8494, -8487, -8476, -8465, -8462, -8452, -8449, -8445, -8440, -8433, -8430, -8407, -8405, -8400, -8399, -8392, -8389, -8388, -8377, -8374, -8365, -8353, -8352, -8348, -8347, -8335, -8310, -8294, -8287, -8285, -8283, -8282, -8280, -8265, -8260, -8257, -8255, -8253, -8249, -8248, -8241, -8230, -8221, -8198, -8195, -8193, -8176, -8171, -8170, -8166, -8160, -8150, -8142, -8124, -8111, -8110, -8105, -8092, -8088, -8076, -8061, -8058, -8057, -8055, -8048, -8039, -8030, -8012, -8011, -7996, -7974, -7940, -7936, -7934, -7929, -7925, -7921, -7918, -7911, -7907, -7906, -7901, -7897, -7890, -7887, -7885, -7884, -7881, -7880, -7879, -7871, -7870, -7863, -7853, -7852, -7849, -7844, -7840, -7839, -7837, -7826, -7824, -7818, -7804, -7800, -7797, -7786, -7784, -7772, -7762, -7751, -7740, -7729, -7728, -7713, -7701, -7688, -7685, -7681, -7676, -7671, -7667, -7666, -7665, -7659, -7658, -7655, -7648, -7645, -7628, -7624, -7618, -7614, -7612, -7607, -7598, -7596, -7593, -7588, -7581, -7579, -7577, -7573, -7570, -7565, -7562, -7555, -7553, -7539, -7537, -7532, -7530, -7515, -7499, -7498, -7497, -7496, -7488, -7483, -7479, -7471, -7470, -7468, -7460, -7450, -7447, -7435, -7429, -7427, -7425, -7414, -7405, -7404, -7403, -7393, -7392, -7380, -7372, -7345, -7343, -7341, -7336, -7335, -7332, -7315, -7308, -7306, -7302, -7297, -7287, -7286, -7284, -7280, -7277, -7276, -7270, -7250, -7246, -7245, -7243, -7237, -7225, -7220, -7203, -7201, -7197, -7194, -7193, -7163, -7154, -7141, -7131, -7130, -7124, -7113, -7110, -7105, -7089, -7084, -7073, -7071, -7064, -7054, -7045, -7043, -7039, -7033, -7026, -7017, -7012, -7009, -7001, -6995, -6992, -6989, -6987, -6983, -6982, -6976, -6974, -6971, -6941, -6928, -6924, -6920, -6919, -6917, -6916, -6914, -6912, -6883, -6879, -6872, -6871, -6867, -6862, -6859, -6857, -6844, -6838, -6824, -6823, -6818, -6816, -6811, -6805, -6798, -6790, -6783, -6780, -6778, -6769, -6762, -6756, -6733, -6721, -6720, -6718, -6704, -6699, -6697, -6696, -6695, -6692, -6690, -6686, -6682, -6679, -6670, -6669, -6668, -6665, -6658, -6651, -6650, -6649, -6647, -6644, -6642, -6633, -6632, -6624, -6618, -6616, -6615, -6606, -6589, -6588, -6586, -6584, -6574, -6573, -6571, -6567, -6556, -6553, -6549, -6540 ...
# dict

# %%
# binary search functin
def binary_search(in_array, target):

    # Initialize left and right pointers
    left = 0
    right = len(in_array) - 1

    # Binary search
    while left <= right:
        mid = (left + right) // 2
        if in_array[mid] == target:
            return mid
        elif in_array[mid] < target:
            left = mid + 1
        else:
            right = mid - 1

    # Return -1 if the element is not found
    return -1

# %%
# Get the current directory where the script is located
current_directory = os.getcwd()

# Define the database directory (change this to your actual directory name)
database_directory = "database"

# Construct the full path to the database directory
database_path = os.path.join(current_directory, database_directory)

# Check if the directory exists
if os.path.exists(database_path) and os.path.isdir(database_path):
    # List all files in the directory
    files = os.listdir(database_path)
    
    # Print the list of files
    for file_name in files:

        file_path = os.path.join(database_path, file_name)
        print(file_name)
        if os.path.isfile(file_path):
                try:
                    with open(file_path, "r") as file:
                        data = json.load(file)
                        data['problem_name'] = file_name.replace('.json', '')
                        inserted_object = collection.insert_one(data)
                        print(f"Uploaded file: {file_path}, Object ID: {inserted_object.inserted_id}")
                except Exception as e:
                    print(f"Error uploading file {file_path}: {str(e)}")

else:
    print(f"Database directory '{database_path}' does not exist.")
